# %% [markdown]
# ---
# **Observation:**
#
# 1. Null values are present in the following columns:
#    - **`videoDefaultLanguage`**  (will be dropped after data cleaning)
#    - **`videoDefaultAudioLanguage`**
#    - **`channelCountry`**
#
# ---
#
# 2. The following columns will be dropped as part of data cleaning:
#    - **`videoDescription`**: Reserved for analysis in future NLP project with a broader dataset.
#    - **`videoLiveBroadcastContent`**: All values are `'none'`, providing no variability or insights.
#    - **`videoFavoriteCount`**: All values are `0`, making it redundant.
#    - **`videoTags`**: Reserved for analysis in future NLP project with a broader dataset.
#    - **`videoUniqueId`**: Identified as a duplicate column.
#    - **`channelIdUnique`**: Identified as a duplicate column.
#    - **`channelTitleCheck`**: Identified as a duplicate column.
#    - **`channelDescription`**: Reserved for analysis in future NLP project with a broader dataset.
# ---
#
# 3. The columns **`channelName`** and **`videoTitle`** require further processing due to the presence of:
#     - Multilingual text.
#     - Emojis and special characters.
#
# ---

# %%
# !pip install deep_translator
# !pip install emoji
# Out:
# Collecting deep_translator
#   Downloading deep_translator-1.11.4-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.9.1 in /usr/local/lib/python3.10/dist-packages (from deep_translator) (4.12.3)
# Requirement already satisfied: requests<3.0.0,>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from deep_translator) (2.32.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4<5.0.0,>=4.9.1->deep_translator) (2.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.23.0->deep_translator) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.23.0->deep_translator) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.23.0->deep_translator) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.23.0->deep_translator) (2024.12.14)
# Downloading deep_translator-1.11.4-py3-none-any.whl (42 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 kB 1.7 MB/s eta 0:00:00
# Installing collected packages: deep_translator
# Successfully installed deep_translator-1.11.4
# Requirement already satisfied: emoji in /usr/local/lib/python3.10/dist-packages (2.14.0)

# %%
def Source_File_Extraction(repo_url,kaggle_repo_url):
    if os.path.exists(kaggle_repo_url):
        print("Already cloned and the repo file exists")
        repo = git.Repo(kaggle_repo_url)  # Access the existing repository
        origin = repo.remote(name='origin')  # Get the remote repository
        origin.pull()  # Pull the latest changes from the repository
        print("Successfully pulled the git repo before push")
    else:
        # Clone the repository if it doesn't exist
        repo = git.Repo.clone_from(repo_url, kaggle_repo_url)
        print("Successfully cloned the git repo")
    output_files = os.listdir(source_path)
    Target_File = max([i for i in output_files if i.startswith("S_") and i.endswith('records.json')])
    Target_File = pd.read_json(f'{source_path}/{Target_File}')
    return Target_File

# %% [markdown]
# ---

# %%
def DataCleaning(Target_File):
    # Dropped the columns
    Target_File = Target_File.drop(['videoDescription','videoLiveBroadcastContent','videoFavoriteCount','videoTags','videoUniqueId','channelIdUnique','channelTitleCheck','channelDescription'],axis=1)
    
    # Removing Duplicates
    Target_File  = Target_File.drop_duplicates(ignore_index=True)
    
    # Remving the videos which has videoDefaultAudioLanguage as None or not starts with en
    Target_File_EN = Target_File[Target_File['videoDefaultAudioLanguage'].str.startswith("en",na=False)].reset_index(drop=True)

    for i in range(len(Target_File_EN['channelName'])):
        try:
            # Check and translate non-ASCII characters
            if not Target_File_EN['channelName'][i].isascii():
                Target_File_EN.loc[i, 'channelName'] = GoogleTranslator(source='auto', target='en').translate(Target_File_EN['channelName'][i])
            if not Target_File_EN['videoTitle'][i].isascii():
                Target_File_EN.loc[i, 'videoTitle'] = GoogleTranslator(source='auto', target='en').translate(Target_File_EN['videoTitle'][i])
    
            # Remove emojis
            Target_File_EN.loc[i, 'channelName'] = emoji.replace_emoji(Target_File_EN['channelName'][i], replace='')
            Target_File_EN.loc[i, 'videoTitle'] = emoji.replace_emoji(Target_File_EN['videoTitle'][i], replace='')
    
            # Decode HTML entities like &amp; and &#39;
            Target_File_EN.loc[i, 'channelName'] = html.unescape(Target_File_EN['channelName'][i])
            Target_File_EN.loc[i, 'videoTitle'] = html.unescape(Target_File_EN['videoTitle'][i])
    
            # Remove non-ASCII characters
            Target_File_EN.loc[i, 'channelName'] = re.sub(r'[^\x00-\x7F]+', '', Target_File_EN['channelName'][i])
            Target_File_EN.loc[i, 'videoTitle'] = re.sub(r'[^\x00-\x7F]+', '', Target_File_EN['videoTitle'][i])
    
            # print(Target_File_EN['channelName'][i])
            # print(Target_File_EN['videoTitle'][i])
        except Exception as e:
            print(e)
    
    # Removing Duplicates
    Target_File_EN  = Target_File_EN.drop_duplicates(ignore_index=True)
    Target_File_EN = Target_File_EN.drop(['videoDefaultLanguage'],axis=1)
    Target_File_EN['channelCountry'] = Target_File_EN['channelCountry'].fillna('Unknown')
    return Target_File_EN

# %%
def GitHubPush(Target_File_EN):
    record_count = len(Target_File_EN)
    
    # Generate a timestamp for the file name using the current time in IST (Indian Standard Time).
    timestamp = datetime.datetime.now(ist).strftime("%Y-%m-%d_%H:%M:%S")
    
    # Create a filename using the generated timestamp to ensure uniqueness with number of records.
    filename = f"DC_{timestamp}_{record_count}_records.json"
    
    # Save the DataFrame to a JSON file with readable formatting.
    Target_File_EN.to_json(filename, orient="records", indent=4)
    print(f"DataFrame saved as {filename}")
    
    if not os.path.exists(destination_path):
        # Create the destination directory if it doesn't exist
        os.makedirs(destination_path)
        print('created the destination directory, DataCleaning/Daily')
        shutil.copyfile(f'/kaggle/working/{filename}', f'{destination_path}/{filename}')
    else:
        print('Destination directory already exists')
        shutil.copyfile(f'/kaggle/working/{filename}', f'{destination_path}/{filename}')
    
    # Initialize the repository for git operations
    repo = Repo(kaggle_repo_url)
    
    # Add the copied file to the staging area
    repo.index.add([f"{destination_path}/{filename}"])
    
    # Create a timestamp for the commit message
    timestamp = datetime.datetime.now(ist).strftime("%Y-%m-%d_%H:%M:%S")
    # Commit the changes with a message including the timestamp
    repo.index.commit(f"{timestamp} Added files from Kaggle notebook, {filename}")
    
    # Push the changes to the remote repository
    origin = repo.remote(name="origin")
    push_result = origin.push()
    if push_result:
        print("Push successful.")
    else:
        print("Push failed.")

# %%
def main():
    Source_File = Source_File_Extraction(repo_url,kaggle_repo_url)
    Cleaned_File = DataCleaning(Source_File)
    display(Cleaned_File.sort_values(by='videoDurationInSeconds',ascending = True))
    GitHubPush(Cleaned_File)

# %%
if __name__ == "__main__":
    import os  
    import git 
    from git import Repo  
    import datetime  
    from pytz import timezone
    import pandas as pd
    import deep_translator
    from deep_translator import GoogleTranslator
    from pytz import timezone 
    import shutil
    import emoji
    import re
    import html
    from kaggle_secrets import UserSecretsClient
    user_secrets = UserSecretsClient()
    secret_value_0 = user_secrets.get_secret("dataCleanRepoUrl")
    repo_url = secret_value_0
    ist = timezone('Asia/Kolkata')
    kaggle_repo_url = '/kaggle/working/YouTubeFoodChannelAnalysis'
    destination_path = '/kaggle/working/YouTubeFoodChannelAnalysis/DataCleaning/Daily'
    source_path = '/kaggle/working/YouTubeFoodChannelAnalysis/Source/Daily'
    # Below script prevents all columns and rows from getting truncated while display
    pd.set_option("display.max_columns", None)
    pd.set_option("display.max_rows",None)
    main()
# Out:
# Successfully cloned the git repo
#                     channelId                                  channelName  \
# 215  UCiPMh3oIcVee2Q2p8_W-lxg                          Blujay Technologies
# 406  UCXddspaT5bYIQ9133GPYQdQ                             Integrity Vision
# 318  UCuVZCbckCp0O49wlvkcDnbA                               Glitter Brains
# 307  UCzUEbiVPFhuRvkwYFbGPALg                         The Resume Whisperer
# 153  UC4PSydHaXya-VSrgFCdRULA                       The Deep Stack Podcast
# 395  UCBwSCyzT3GukpVdUdxMjKYw                                 Red Hat EMEA
# 412  UCbrXRQHV4TOU4Pqzw325Z1A                                  Pluralsight
# 325  UCJFBnZFBlHfuSWdLM4jX9bw                                  OutOfDevOps
# 329  UCmIIOHKgJnGQruIVD_Zx71g                                    Sleuth TV
# 348  UCaJpQyYXpTlMoHHZuuaTTug                                 Oleg Shelaev
# 321  UCbBoXUu5exct-PieTYDBNDA                      Better Dev with Anubhav
# 255  UCJS9pqu9BzkAMNTmzNMNhvg                            Google Cloud Tech
# 377  UCwup1SNVxsJig4CrvWLK6_Q                          DevOps Pro Junction
# 342  UCJFBnZFBlHfuSWdLM4jX9bw                                  OutOfDevOps
# 109  UCF-uUxo43IPpnEwnR62WGlA                        Learn with Whiteboard
# 300  UCIkKtuTtFmD7J8h34dKwmtQ                               vikrant hodage
# 399  UCwup1SNVxsJig4CrvWLK6_Q                          DevOps Pro Junction
# 130  UCF-uUxo43IPpnEwnR62WGlA                        Learn with Whiteboard
# 182  UCyU5wkjgQYGRB0hIHMwm2Sg                                       Syntax
# 409  UC8w8_H_1uDfi2ftQx7a64uQ                Software and Testing Training
# 418  UC8w8_H_1uDfi2ftQx7a64uQ                Software and Testing Training
# 400  UCqCH_Ihcbzz1bNu5TAkXuQw                                     Humalect
# 172  UCkJcAZRJOHzSkqqcOejF2wg                                     CodeBite
# 416  UCTUaRWNhK3aWX3lxudsEExw                                     Sematext
# 151  UCBwSCyzT3GukpVdUdxMjKYw                                 Red Hat EMEA
# 207  UCTUaRWNhK3aWX3lxudsEExw                                     Sematext
# 344  UCAc45SVFATruhRe_kb1iGkA                             Cameron McKenzie
# 426  UCfpf-vjGm_54leJWcAWTiYA                                 TheCodeCloud
# 186  UC0m-80FnNY2Qb7obvTL_2fA                              Microsoft Azure
# 142  UCnMGQ8QHMAnVIsI3xJrihhg                                       GitLab
# 419  UCww9_iYCeH5CjVDA5Fd5H6w                                    DevOps_PM
# 192  UCTUaRWNhK3aWX3lxudsEExw                                     Sematext
# 360  UCqCH_Ihcbzz1bNu5TAkXuQw                                     Humalect
# 311  UC6cWAhkV-_V5tvZDRMo5q2A                               Code With Ymir
# 314  UCzd8R3vkpllD4CJn_5g5sKg                                 VMware Tanzu
# 73   UCJS9pqu9BzkAMNTmzNMNhvg                            Google Cloud Tech
# 179  UCzWd8lsefYoh42OCrg6FzuQ                                BestITCourses
# 384  UCI7PyePh-cMIDMAuKCSF3_A                               QA Underground
# 242  UCa8wSbVGmRM3PZCMQOvwsvA                               Picnic Careers
# 414  UCf9DABumLQQ1Dw60cdSn0gA                               Tech and Solve
# 369  UCQjE37R-Y4DTq7kUWPO83Wg                     ServiceNow Documentation
# 336  UCjzLMNEp_7PjRyOrCFz_Big                         Bluelight Consulting
# 231  UC0m-80FnNY2Qb7obvTL_2fA                              Microsoft Azure
# 410  UCV9iiLYQ81JTkrn-ObGwb7w                           Tensure Consulting
# 319  UCFctzkc2Xb4_O76SlTZsjkg                              Beyond Identity
# 120  UC-ikyViYMM69joIAv7dlMsA                              DevOps on Azure
# 273  UCd6MoB9NC6uYN2grvUNT-Zg                          Amazon Web Services
# 94   UCp6NUFV9mSEK6RxUiEVymVg                                      Red Hat
# 190  UCmq2pG9uYmTvqaN5QIfZeyw  U.S. Government Accountability Office (GAO)
# 347  UCMAg8ZG-BUrVYsQzlM3bHMA                     Global DevOps Experience
# 37   UCbidO9aJEDNXZNTVZ6ReZ4g                         ValueOps by Broadcom
# 315  UCN_QTTqTo4RKaa92VxM298g                                       Devart
# 299  UCqrPQYmIxbk3Wo_w594pEEA                              USAF Kessel Run
# 103  UC0m-80FnNY2Qb7obvTL_2fA                              Microsoft Azure
# 203  UCjGcthjRHGegI8TeJHMS6wA                                 LogicOps Lab
# 290  UCsMica-v34Irf9KVTh6xx-g                          Microsoft Developer
# 227  UCjGcthjRHGegI8TeJHMS6wA                                 LogicOps Lab
# 221  UCpcndhe5IebWrJrdLRGRsvw                              Oracle Learning
# 328  UCAdEqOhSnzlLBtaapu567AQ                   Hewlett Packard Enterprise
# 305  UCsMica-v34Irf9KVTh6xx-g                          Microsoft Developer
# 376  UCMAg8ZG-BUrVYsQzlM3bHMA                     Global DevOps Experience
# 34   UCp06FAzrFalo3txskS1gCfA                                    GitKraken
# 28   UCkw4JCwteGrDHIsyIIKo4tQ                                     edureka!
# 197  UCsMica-v34Irf9KVTh6xx-g                          Microsoft Developer
# 274  UCSFrXfvSJBThkMa09keI-SQ                                        Quest
# 245  UCTMRxtyHoE3LPcrl-kT4AQQ                                 Google Cloud
# 309  UCqTHH2UWv05c2U3pawrQ6jQ                                          AVL
# 270  UC0m-80FnNY2Qb7obvTL_2fA                              Microsoft Azure
# 379  UCQjE37R-Y4DTq7kUWPO83Wg                     ServiceNow Documentation
# 233  UCTMRxtyHoE3LPcrl-kT4AQQ                                 Google Cloud
# 212  UC-ikyViYMM69joIAv7dlMsA                              DevOps on Azure
# 401  UCpPg789a-SRZrcQ0GoH74KA                                      Bitrise
# 385  UC30jJ6o-3BCfTgYdwf-XixQ                                  Luiz Macedo
# 176  UC3-kH9Aq4s-TLTWodBiGLYg                                solarwindsinc
# 39   UCJGCg4rB3QSs8y_1FquelBQ                       Microsoft Dynamics 365
# 394  UCm9OU61xNzeKY2-3jQ5322w                                       Intriq
# 214  UCwtWvjI4Ph_PEmL7KYBRzcA                                        Mezmo
# 244  UCqTHH2UWv05c2U3pawrQ6jQ                                          AVL
# 170  UC-ikyViYMM69joIAv7dlMsA                              DevOps on Azure
# 316  UCJS9pqu9BzkAMNTmzNMNhvg                            Google Cloud Tech
# 53   UCkcSqKNo-_hBeknZEhsIRng                                   Mark Shead
# 271  UC07b9GB8a-4c6-T6pd2bbBQ                                  HCLSoftware
# 131  UC-ikyViYMM69joIAv7dlMsA                              DevOps on Azure
# 378  UCZNlvVzPwK2CkkVKiCXezOA                          Lionel Gurret - MVP
# 163  UC-ikyViYMM69joIAv7dlMsA                              DevOps on Azure
# 126  UCp6NUFV9mSEK6RxUiEVymVg                                      Red Hat
# 193  UCJS9pqu9BzkAMNTmzNMNhvg                            Google Cloud Tech
# 291  UCSgzRJMqIiCNtoM6Q7Q9Lqw                              Microsoft Cloud
# 262  UCMl_1_jjnhgPAsRBuJ0yzAA                          Gleek diagram maker
# 113  UCpXZGFBjshrNCmt_uAcLXkQ                                      Litwire
# 33   UCMndKhkWZp9EOWPrRI4V6bA        Software Engineering With Scott Moore
# 162  UCUEntbgFH1B-0E5NaSIIijg                                base2Services
# 333  UCdCfNyB3Gpa2TGOQ72me_6w       Mondoo - The Unified Security Platform
# 100  UC-e2aGRMGMl67MDJoqcj19Q                                  Eye on Tech
# 258  UC0m-80FnNY2Qb7obvTL_2fA                              Microsoft Azure
# 278  UCo2IXZej8qNyIbbWWCG9z3Q                                       Copado
# 93   UC0YiyXX0xhZ27o2F5qawaCA                                  TestGorilla
# 104  UC8cc4pVKVHG7A9fbNsRNrLQ                                          IBM
# 158  UCKWaEZ-_VweaEx1j62do_vQ                               IBM Technology
# 323  UCFNSJV7uuvCmW2BRe-xvZWQ        ClickIT DevOps & Software Development
# 380  UCKeQgxVo5A7zevOUts6Lxfw                  CISCONET Training Solutions
# 279  UCJFBnZFBlHfuSWdLM4jX9bw                                  OutOfDevOps
# 177  UC0m-80FnNY2Qb7obvTL_2fA                              Microsoft Azure
# 189  UC0m-80FnNY2Qb7obvTL_2fA                              Microsoft Azure
# 392  UCWbRI_OWogTqAf-SgBzeYDA                                 Calian Group
# 292  UCQjE37R-Y4DTq7kUWPO83Wg                     ServiceNow Documentation
# 306  UCu8Z6SAMnsng_sf3908k5ug                             Flying Donkey IT
# 228  UCa4EzKOhB3Hobr19CUvsYEg                                       Simova
# 367  UCzWd8lsefYoh42OCrg6FzuQ                                BestITCourses
# 368  UC0Wun_r_Ub1P--d8XJCSPgw                       HORIZONT Software GmbH
# 282  UCGZiVVLpIRNFbj2EtA9dhYw             Lepczynski Tech Cloud Adventures
# 353  UCD7dFJu5VfyjJU5n-vwS1Zw                                       Prodly
# 257  UCJS9pqu9BzkAMNTmzNMNhvg                            Google Cloud Tech
# 236  UCJPYBmnie7I6b62LOVFdWqQ                                 Rajesh Yadav
# 283  UCbOutTxbTmB4Dk1R5OsIZIg                                        Unito
# 83   UC3gO0o6xe18NQ-TvJOXXCKA                          upGrad KnowledgeHut
# 41   UCffTivfUMtw8VOjWAT9tBrw                                 Arora's Life
# 420  UCUQJBpvMT7kKcpS8bGOmK3A                                       YohDev
# 345  UCTLFNCGOENtbTTZqPYKaXaw                                      Exalate
# 383  UCFFLP0dKesrKWccYscdAr9A                              theurbanpenguin
# 116  UCKjVI0LawDxHaXSBMBOK1tA                         Platform Engineering
# 366  UCTlo7dk8tb2w-ymZ7oV55ug                               Jarrett Coggin
# 275  UCvxGFOnwUBDHHcxuPqhe4CQ                                       Upwork
# 293  UCFNSJV7uuvCmW2BRe-xvZWQ        ClickIT DevOps & Software Development
# 223  UCbOutTxbTmB4Dk1R5OsIZIg                                        Unito
# 146  UC5ZR5TkAP7T7e__FIsDtMdw                                     iTrellis
# 338  UCFNSJV7uuvCmW2BRe-xvZWQ        ClickIT DevOps & Software Development
# 374  UCzd8R3vkpllD4CJn_5g5sKg                                 VMware Tanzu
# 381  UCMndKhkWZp9EOWPrRI4V6bA        Software Engineering With Scott Moore
# 269  UCFNSJV7uuvCmW2BRe-xvZWQ        ClickIT DevOps & Software Development
# 86   UCa_dhTSMGkW5lMof4tsEiHA                                Coder Society
# 122  UC5ZR5TkAP7T7e__FIsDtMdw                                     iTrellis
# 302  UCW0UksckiL3ZF7Hd-MsU15g                                   MentorMate
# 25   UC7c3Kb6jYCRj4JOHHZTxKsQ                                       GitHub
# 154  UCbOutTxbTmB4Dk1R5OsIZIg                                        Unito
# 38   UCZgt6AzoyjslHTC9dz0UoTw                                   ByteByteGo
# 121  UCZGGwqjk5jfO4vN1SOCJ2ew                       Digital Cloud Training
# 134  UCnMGQ8QHMAnVIsI3xJrihhg                                       GitLab
# 417  UCZNlvVzPwK2CkkVKiCXezOA                          Lionel Gurret - MVP
# 340  UCDlhC4hMJzEHSzH1iWaCjmg                                     TeKanAid
# 286  UCHz7v_yrP4iEWqylooyCm9A                               MarkInTheCloud
# 69   UCMndKhkWZp9EOWPrRI4V6bA        Software Engineering With Scott Moore
# 346  UCvOJU-ubyUqxGSDRN7xK4Ng                                   neptune_ai
# 334  UCh_bSyL_Ioa3vZ2h4rCQsEA                              The Serious CTO
# 65   UCT-nPlVzJI-ccQXlxjSvJmw                               AWS Developers
# 354  UCh2hNg76zo3d1qQqTWIQxDg                                        JFrog
# 6    UCJS9pqu9BzkAMNTmzNMNhvg                            Google Cloud Tech
# 253  UCZD2ggK3cnVD_sLMR6gUx2w                                         Civo
# 408  UCZNlvVzPwK2CkkVKiCXezOA                          Lionel Gurret - MVP
# 421  UChXZvgs_Ulv_xGkDm2eoVFg                                    Sumit Raj
# 259  UCJS9pqu9BzkAMNTmzNMNhvg                            Google Cloud Tech
# 152  UC584BS_wFEuDIkvb7bIFk8A                               Jinget dot NET
# 317  UCJ0AhC-qsQdc_gUk-kOOs5Q                                      Eficode
# 403  UCZNlvVzPwK2CkkVKiCXezOA                          Lionel Gurret - MVP
# 422  UCV1ETk4FEWW_QyG1GVOg39g                                    RRTechPro
# 361  UCNIOHOhgmypXQdkviMvMiSQ                            DevOpsDays London
# 140  UCinFZLKr2-UNX23GgH-zeEA                                 CoachForSure
# 219  UCsMica-v34Irf9KVTh6xx-g                          Microsoft Developer
# 26   UCKWaEZ-_VweaEx1j62do_vQ                               IBM Technology
# 220  UCsMica-v34Irf9KVTh6xx-g                          Microsoft Developer
# 261  UCXRZyv0cNwba6f0xCREAD_Q                                     Geekific
# 48   UCJS9pqu9BzkAMNTmzNMNhvg                            Google Cloud Tech
# 124  UCnMGQ8QHMAnVIsI3xJrihhg                                       GitLab
# 125  UC5ZR5TkAP7T7e__FIsDtMdw                                     iTrellis
# 352  UCDp3fXx_kGPDM5kn6oMG-3Q                        Cloud Architect Rahul
# 312  UCnd94o169CbOIJyiEUkTL2A                               Lucid Software
# 156  UCInaXw2vm6DfEW0tBhUFdbA                     Neudesic, an IBM Company
# 339  UCZEsU-JpH3a9n9xBY4xlHAw                                    azurewala
# 391  UC_bJ9Hqj_6uX9f-nNsWMt6A                          JOYATRES TECHNOLOGY
# 308  UCFNSJV7uuvCmW2BRe-xvZWQ        ClickIT DevOps & Software Development
# 101  UCKWaEZ-_VweaEx1j62do_vQ                               IBM Technology
# 372  UCSzpVDEYi2R3CJAjW7bM3ew                                 NUCIDA Group
# 201  UC5ZFyTivwhmZXUcOoMavyAQ                        DevOps For Developers
# 79   UCSWj8mqQCcrcBlXPi4ThRDQ                                    KodeKloud
# 301  UCMy8psUTJzMfTuoLnr3-9hQ                              Techtonic Shift
# 370  UCcz_P5ztha3Tn-qkcTvKgxQ                                 Semaphore CI
# 106  UCp8lLM2JP_1pv6E0NQ38pqw                                 A Cloud Guru
# 349  UCbMONiRSiUzvuyBldnsDT_g                               Danilo Pianini
# 295  UCuUvJx7xB1vQDRf6w8VwKIw                                       OpsHub
# 211  UCxm6ZcNMXMrckKRJPXlDu_w                                     AOS Note
# 76   UCJ9905MRHxwLZ2jeNQGIWxA                          Microsoft Mechanics
# 284  UCfDZF0pWhNjJO_kpPozr8Tg  Dara Oladapo | Code, Cloud, DevOps, Devices
# 423  UCBhXFK70DbOU15N2BhDQVTg                              All Things Open
# 413  UCJ0AhC-qsQdc_gUk-kOOs5Q                                      Eficode
# 92   UCYCwgQAMm9sTJv0rgwQLCxw                                      Grafana
# 205  UC5ZFyTivwhmZXUcOoMavyAQ                        DevOps For Developers
# 396  UCcz_P5ztha3Tn-qkcTvKgxQ                                 Semaphore CI
# 217  UCp0yzfkQVr1YG1R1DWxUl7Q                                   Arien Kock
# 165  UCSWj8mqQCcrcBlXPi4ThRDQ                                    KodeKloud
# 183  UC-ikyViYMM69joIAv7dlMsA                              DevOps on Azure
# 50   UCMndKhkWZp9EOWPrRI4V6bA        Software Engineering With Scott Moore
# 191  UCsZ4IlYjjVxqe5OZ14tyh5g                      Azure Synapse Analytics
# 75   UCbg9O0JF3rVKev6wpI5_u5g                                  Cloud Champ
# 180  UC5ayzs2Jp3biNZscB3qacmw                               Round The Code
# 20   UCJS9pqu9BzkAMNTmzNMNhvg                            Google Cloud Tech
# 19   UC0m-80FnNY2Qb7obvTL_2fA                              Microsoft Azure
# 74   UCMndKhkWZp9EOWPrRI4V6bA        Software Engineering With Scott Moore
# 46   UCKWaEZ-_VweaEx1j62do_vQ                               IBM Technology
# 23   UC2Us1KkV7BMm5Rp6tV6tTxg                                    WebGentle
# 129  UCVUJR1wV31gh6hqFouEpTNQ                        ThoughtfulTechy Cloud
# 11   UCkw4JCwteGrDHIsyIIKo4tQ                                     edureka!
# 98   UCMndKhkWZp9EOWPrRI4V6bA        Software Engineering With Scott Moore
# 389  UCdc9jgeO6DThm-b4mHmW6dA                   Rakia Ben Sassi | TekForge
# 359  UCFNSJV7uuvCmW2BRe-xvZWQ        ClickIT DevOps & Software Development
# 95   UCSWj8mqQCcrcBlXPi4ThRDQ                                    KodeKloud
# 144  UCF-uUxo43IPpnEwnR62WGlA                        Learn with Whiteboard
# 310  UCm4k60PrYkebIgd48XJtO3g                      Driving Digital Standup
# 85   UCV9_KctSID2YB54ynA_VgIg                        Scrum Master In Black
# 297  UCH1Rcqy0n1gY8O2scN2nVAA                                  IT Cheer Up
# 280  UCFFLP0dKesrKWccYscdAr9A                              theurbanpenguin
# 128  UCXvlc9x4zlv5DEqbby55Ivg                                  Romano Roth
# 55   UCSWj8mqQCcrcBlXPi4ThRDQ                                    KodeKloud
# 398  UCUQJBpvMT7kKcpS8bGOmK3A                                       YohDev
# 248  UCsMica-v34Irf9KVTh6xx-g                          Microsoft Developer
# 78   UCbg9O0JF3rVKev6wpI5_u5g                                  Cloud Champ
# 304  UC7bUjNTtLIZU1mBbD5N0Kdg                                Gaurav Sharma
# 96   UCYCwgQAMm9sTJv0rgwQLCxw                                      Grafana
# 234  UCT-nPlVzJI-ccQXlxjSvJmw                               AWS Developers
# 356  UCcz_P5ztha3Tn-qkcTvKgxQ                                 Semaphore CI
# 326  UCa1zuotKU4Weuw_fLRnPv0A                                  Vue Mastery
# 12   UCTt7pyY-o0eltq14glaG5dg                      Automation Step by Step
# 159  UCzWd8lsefYoh42OCrg6FzuQ                                BestITCourses
# 137  UCzWd8lsefYoh42OCrg6FzuQ                                BestITCourses
# 263  UCaCU2W8q6eYOPpdxcFKfCVA                                     TestRail
# 77   UCsUalyRg43M8D60mtHe6YcA                                     Honeypot
# 119  UCUDKcm1wIfE6EWk_SyK0D4w                            Fortify Unplugged
# 54   UCSWj8mqQCcrcBlXPi4ThRDQ                                    KodeKloud
# 397  UC52NUNDtZ2FcV4q9ZZH3MJg                    Empower Through Knowledge
# 382  UCZNlvVzPwK2CkkVKiCXezOA                          Lionel Gurret - MVP
# 110  UC-ikyViYMM69joIAv7dlMsA                              DevOps on Azure
# 393  UCrR-FReRHFqw-c2gxYnD_cw                                Tech Apricate
# 59   UCKWaEZ-_VweaEx1j62do_vQ                               IBM Technology
# 198  UC-ikyViYMM69joIAv7dlMsA                              DevOps on Azure
# 288  UCd6MoB9NC6uYN2grvUNT-Zg                          Amazon Web Services
# 30   UCdngmbVKX1Tgre699-XLlUA                          TechWorld with Nana
# 133  UCd6MoB9NC6uYN2grvUNT-Zg                          Amazon Web Services
# 70   UCNFmBuclxQPe57orKiQbyfA                                 Tanay Pratap
# 49   UC5ZFyTivwhmZXUcOoMavyAQ                        DevOps For Developers
# 209  UCH912uDFX3sIaPXMrJa9X_w                                    Questpond
# 168  UC5ZR5TkAP7T7e__FIsDtMdw                                     iTrellis
# 61   UC5ZFyTivwhmZXUcOoMavyAQ                        DevOps For Developers
# 58   UC-ikyViYMM69joIAv7dlMsA                              DevOps on Azure
# 51   UCCktnahuRFYIBtNnKT5IYyg                                  Intellipaat
# 111  UCCktnahuRFYIBtNnKT5IYyg                                  Intellipaat
# 281  UC-ikyViYMM69joIAv7dlMsA                              DevOps on Azure
# 45   UCrtPXCqjm9c7nqgJL-vBSZg                                   CareerVidz
# 276  UCFNSJV7uuvCmW2BRe-xvZWQ        ClickIT DevOps & Software Development
# 91   UCJS9pqu9BzkAMNTmzNMNhvg                            Google Cloud Tech
# 185  UCqvV0NGWUdnQ0GPuqTNKYLg                              Artem Grabovski
# 332  UCuUvJx7xB1vQDRf6w8VwKIw                                       OpsHub
# 21   UCYeiozh-4QwuC1sjgCmB92w                               DevOps Toolbox
# 404  UC30jJ6o-3BCfTgYdwf-XixQ                                  Luiz Macedo
# 216  UCe4vfjTMNzHho7Yg-5jHq1w                                TheCloudsGuru
# 24   UCAr20GBQayL-nFPWFnUHNAA                                Frank Boucher
# 99   UC-ikyViYMM69joIAv7dlMsA                              DevOps on Azure
# 10   UC2Us1KkV7BMm5Rp6tV6tTxg                                    WebGentle
# 105  UCt9C1JhrIKfzdPpZjoT8Yfw                       CursorRun | Tech Talks
# 175  UC-ikyViYMM69joIAv7dlMsA                              DevOps on Azure
# 141  UC7c3Kb6jYCRj4JOHHZTxKsQ                                       GitHub
# 324  UCTlo7dk8tb2w-ymZ7oV55ug                               Jarrett Coggin
# 251  UCJPYBmnie7I6b62LOVFdWqQ                                 Rajesh Yadav
# 195  UCcdv38QxPjSMqbt5ffLhJLA                                    Tailscale
# 267  UCLfxdtB3H0JdnniBnd4DoNA                                       Turing
# 143  UC0m-80FnNY2Qb7obvTL_2fA                              Microsoft Azure
# 424  UCy1a2QSDVZNDwZf7KbNmoHQ                                 Tech Tweedie
# 80   UCCktnahuRFYIBtNnKT5IYyg                                  Intellipaat
# 357  UCNwP7KEElaJ7cdDTLP-KbBg                                Azizul maqsud
# 145  UCOSYuY_e_r5GtVdlCVwY83Q                                 Damien Burks
# 88   UCsZ4IlYjjVxqe5OZ14tyh5g                      Azure Synapse Analytics
# 164  UCT-nPlVzJI-ccQXlxjSvJmw                               AWS Developers
# 272  UCdoadna9HFHsxXWhafhNvKw                                   AWS Events
# 364  UCFNSJV7uuvCmW2BRe-xvZWQ        ClickIT DevOps & Software Development
# 47   UCMndKhkWZp9EOWPrRI4V6bA        Software Engineering With Scott Moore
# 150  UCCktnahuRFYIBtNnKT5IYyg                                  Intellipaat
# 173  UCd6MoB9NC6uYN2grvUNT-Zg                          Amazon Web Services
# 232  UCpiTu8kfk-FOGCZDAojLtFA                                       Monica
# 200  UC4s3tv0Qq_OSUBfR735Jc6A                           Microsoft Security
# 247  UCTMRxtyHoE3LPcrl-kT4AQQ                                 Google Cloud
# 148  UC7vu7dtHKiy_eRdPe_UUQwQ                                  Rai Gurukul
# 147  UC-ikyViYMM69joIAv7dlMsA                              DevOps on Azure
# 343  UC58s06zC1P7jlWWmjs1uuPA                                  Debug Agent
# 40   UC4JX40jDee_tINbkjycV4Sg                                Tech With Tim
# 138  UCJ9905MRHxwLZ2jeNQGIWxA                          Microsoft Mechanics
# 57   UCs_tLP3AiwYKwdUHpltJPuA                             GOTO Conferences
# 335  UCLfxdtB3H0JdnniBnd4DoNA                                       Turing
# 56   UCzWd8lsefYoh42OCrg6FzuQ                                BestITCourses
# 226  UC-ikyViYMM69joIAv7dlMsA                              DevOps on Azure
# 90   UC-ikyViYMM69joIAv7dlMsA                              DevOps on Azure
# 63   UCMndKhkWZp9EOWPrRI4V6bA        Software Engineering With Scott Moore
# 181  UC-ikyViYMM69joIAv7dlMsA                              DevOps on Azure
# 64   UCmhUwM2tp6mTk_Cv2pfBarA                                  Avin Techno
# 188  UCsMica-v34Irf9KVTh6xx-g                          Microsoft Developer
# 218  UCT-nPlVzJI-ccQXlxjSvJmw                               AWS Developers
# 117  UCXvlc9x4zlv5DEqbby55Ivg                                  Romano Roth
# 36   UCdngmbVKX1Tgre699-XLlUA                          TechWorld with Nana
# 289  UC4s3tv0Qq_OSUBfR735Jc6A                           Microsoft Security
# 298  UCo__uROISnS0g9USNLTHr8Q                               Server Side Up
# 375  UCe61aOE2IMowT7vkKCccyjw                             NetApp on NetApp
# 62   UCfPEiDVbqZuwWWlUngDitCg                              Dave Does Demos
# 8    UCkw4JCwteGrDHIsyIIKo4tQ                                     edureka!
# 415  UC68rDiSTonVIT032gFjZ_ZQ                       DevSecOps Club - DSOC3
# 22   UCdngmbVKX1Tgre699-XLlUA                          TechWorld with Nana
# 82   UC-8Ba047kFinfgp3sO53qcA                                 ACI Learning
# 225  UCQvdU25Eqk3YS9-QnILhKKQ                                 Thoughtworks
# 224  UCANKprSW5q8hX_O6ghyIN7A              iZenBridge Consultancy Pvt Ltd.
# 206  UCTMRxtyHoE3LPcrl-kT4AQQ                                 Google Cloud
# 322  UCFNSJV7uuvCmW2BRe-xvZWQ        ClickIT DevOps & Software Development
# 187  UCCymWVaTozpEng_ep0mdUyw                                   LambdaTest
# 388  UCJ0AhC-qsQdc_gUk-kOOs5Q                                      Eficode
# 266  UC4s3tv0Qq_OSUBfR735Jc6A                           Microsoft Security
# 210  UCQ7D5ToMxQri986Q69BxVMA                           Deserted Island TV
# 256  UCXvlc9x4zlv5DEqbby55Ivg                                  Romano Roth
# 114  UC0m-80FnNY2Qb7obvTL_2fA                              Microsoft Azure
# 66   UC81Q2wnuk5KqOFVgAbq4nUw                                         Fraz
# 132  UCH912uDFX3sIaPXMrJa9X_w                                    Questpond
# 240  UCTLFNCGOENtbTTZqPYKaXaw                                      Exalate
# 287  UCZHb3OEEJ0WkizEH9ErlgvA                            Dell Technologies
# 199  UCcwP70Mvhu21_tNgJq6bRTQ                                     The Cash
# 204  UC-ikyViYMM69joIAv7dlMsA                              DevOps on Azure
# 89   UCCktnahuRFYIBtNnKT5IYyg                                  Intellipaat
# 277  UCDlhC4hMJzEHSzH1iWaCjmg                                     TeKanAid
# 331  UCK9TqOjs5sq2vAu4vUdgyqg                                    Rangle.io
# 112  UCp5WGgq4BTdIWHQjb9R0V1g                                   Tiyani 365
# 363  UCYzwGkfOqrevO-4TuTjPLwQ                               RSA Conference
# 230  UCZHb3OEEJ0WkizEH9ErlgvA                            Dell Technologies
# 355  UCdoadna9HFHsxXWhafhNvKw                                   AWS Events
# 9    UCdngmbVKX1Tgre699-XLlUA                          TechWorld with Nana
# 285  UCZHb3OEEJ0WkizEH9ErlgvA                            Dell Technologies
# 194  UCCktnahuRFYIBtNnKT5IYyg                                  Intellipaat
# 160  UCENTmbKaTphpWV2R2evVz2A                             James Montemagno
# 265  UCepBEvfydfEQkgRZ-bHbtbg                               Patrick Debois
# 350  UChXZvgs_Ulv_xGkDm2eoVFg                                    Sumit Raj
# 196  UCnjBVI53E-kX7hS_zj0YIeQ                                   Raghav Dua
# 202  UCTMRxtyHoE3LPcrl-kT4AQQ                                 Google Cloud
# 373  UCHCThmyZ-2yWkv0UVeBDdnQ                                       Oracle
# 351  UCZHb3OEEJ0WkizEH9ErlgvA                            Dell Technologies
# 390  UCJ0AhC-qsQdc_gUk-kOOs5Q                                      Eficode
# 254  UCh2hNg76zo3d1qQqTWIQxDg                                        JFrog
# 252  UC5ZFyTivwhmZXUcOoMavyAQ                        DevOps For Developers
# 81   UCCktnahuRFYIBtNnKT5IYyg                                  Intellipaat
# 303  UCfao-LwRY1gf61_PdJ_RWQg                                  CareersTalk
# 123  UCvtT19MZW8dq5Wwfu6B0oxw                                       dotnet
# 5    UCHIbErciyS3Hs0kjAz-at5Q                             Technical Suneja
# 238  UC6iKOXJ9PD-n8DcFPBjLD0w                                 glich.stream
# 27   UC_evcfxhjjui5hChhLE08tQ                          Valaxy Technologies
# 35   UCsvqVGtbbyHaMoevxPAq9Fg                                  Simplilearn
# 213  UCc0VKS5VjmEoJ2tSQT80KVA                                        in4it
# 178  UCdoadna9HFHsxXWhafhNvKw                                   AWS Events
# 313  UCZHb3OEEJ0WkizEH9ErlgvA                            Dell Technologies
# 402  UCSR2-ioTo7Tk7IB3TPSE6_A                        SecurityMetrics, Inc.
# 320  UCNIOHOhgmypXQdkviMvMiSQ                            DevOpsDays London
# 425  UCNwP7KEElaJ7cdDTLP-KbBg                                Azizul maqsud
# 264  UCuA2Zv2FalrabTlyR-0ol7g                                   MHYSA Tech
# 149  UCyMr5AFbKecmI_T7y-EK7PQ                               Naeem Shahzad
# 327  UC_bJ9Hqj_6uX9f-nNsWMt6A                          JOYATRES TECHNOLOGY
# 296  UCJ0AhC-qsQdc_gUk-kOOs5Q                                      Eficode
# 371  UC_bJ9Hqj_6uX9f-nNsWMt6A                          JOYATRES TECHNOLOGY
# 2    UCs_tLP3AiwYKwdUHpltJPuA                             GOTO Conferences
# 118  UCXvlc9x4zlv5DEqbby55Ivg                                  Romano Roth
# 67   UCCktnahuRFYIBtNnKT5IYyg                                  Intellipaat
# 15   UCHIbErciyS3Hs0kjAz-at5Q                             Technical Suneja
# 72   UChcLwzCr8ePUSL86y0OWosg                               Tech with Ajit
# 135  UCXvlc9x4zlv5DEqbby55Ivg                                  Romano Roth
# 365  UCZD2ggK3cnVD_sLMR6gUx2w                                         Civo
# 362  UCZD2ggK3cnVD_sLMR6gUx2w                                         Civo
# 31   UCdngmbVKX1Tgre699-XLlUA                          TechWorld with Nana
# 250  UC0yY6a79pPY9J0ShIHRf6yw                                 DjangoCon US
# 167  UCdMz6KKEDW_1Qqas-ya7S6w                                Beyond Coding
# 157  UCdoadna9HFHsxXWhafhNvKw                                   AWS Events
# 32   UCJS9pqu9BzkAMNTmzNMNhvg                            Google Cloud Tech
# 174  UCdoadna9HFHsxXWhafhNvKw                                   AWS Events
# 52   UCCktnahuRFYIBtNnKT5IYyg                                  Intellipaat
# 229  UCD7dFJu5VfyjJU5n-vwS1Zw                                       Prodly
# 294  UC_bJ9Hqj_6uX9f-nNsWMt6A                          JOYATRES TECHNOLOGY
# 341  UCfao-LwRY1gf61_PdJ_RWQg                                  CareersTalk
# 107  UCJS9pqu9BzkAMNTmzNMNhvg                            Google Cloud Tech
# 241  UCGeqHuR3eUU5tnmgjkqZazw                                      CXOTalk
# 155  UCXvlc9x4zlv5DEqbby55Ivg                                  Romano Roth
# 42   UCHIbErciyS3Hs0kjAz-at5Q                             Technical Suneja
# 268  UCJS9pqu9BzkAMNTmzNMNhvg                            Google Cloud Tech
# 246  UCdoadna9HFHsxXWhafhNvKw                                   AWS Events
# 337  UCFli2iOu67JOdnK74-lKgkg                           Hari's DevOps Flow
# 235  UCFsRlOn7gODgv6WUriLrzXg                                  devtools-fm
# 115  UCCktnahuRFYIBtNnKT5IYyg                                  Intellipaat
# 237  UCzWd8lsefYoh42OCrg6FzuQ                                BestITCourses
# 108  UCdMz6KKEDW_1Qqas-ya7S6w                                Beyond Coding
# 208  UCIvREY3tcAOM4Uiig9as-0g                              Inderjeet Singh
# 184  UCdoadna9HFHsxXWhafhNvKw                                   AWS Events
# 43   UCd6MoB9NC6uYN2grvUNT-Zg                          Amazon Web Services
# 16   UCzWd8lsefYoh42OCrg6FzuQ                                BestITCourses
# 139  UCzWd8lsefYoh42OCrg6FzuQ                                BestITCourses
# 161  UCjGcthjRHGegI8TeJHMS6wA                                 LogicOps Lab
# 243  UCdoadna9HFHsxXWhafhNvKw                                   AWS Events
# 239  UC4TAjYDpNggDwictUA180LA                                      Infosec
# 358  UCbgfIoD4L3rAwl5njinJqjA                       Dear Watson Consulting
# 330  UC3xfbCMLCw1Hh4dWop3XtHg                                    Posit PBC
# 84   UCZD2ggK3cnVD_sLMR6gUx2w                                         Civo
# 136  UCc619-1YEUF19YZoB7c4Xvw                        Azure with ArjunReddy
# 87   UCdoadna9HFHsxXWhafhNvKw                                   AWS Events
# 127  UCyMr5AFbKecmI_T7y-EK7PQ                               Naeem Shahzad
# 386  UCbgfIoD4L3rAwl5njinJqjA                       Dear Watson Consulting
# 171  UCT-nPlVzJI-ccQXlxjSvJmw                               AWS Developers
# 7    UCdngmbVKX1Tgre699-XLlUA                          TechWorld with Nana
# 13   UCkw4JCwteGrDHIsyIIKo4tQ                                     edureka!
# 166  UCzWd8lsefYoh42OCrg6FzuQ                                BestITCourses
# 249  UC5ZR5TkAP7T7e__FIsDtMdw                                     iTrellis
# 407  UCvwoG8xtEeogY7fYNiJ_iQw                       Meritstep Technologies
# 405  UCNwP7KEElaJ7cdDTLP-KbBg                                Azizul maqsud
# 411  UCc0VKS5VjmEoJ2tSQT80KVA                                        in4it
# 387  UCaFoUsYu_1lL20C9IVcsB4Q                                  Join DevOps
# 68   UCCktnahuRFYIBtNnKT5IYyg                                  Intellipaat
# 14   UCH912uDFX3sIaPXMrJa9X_w                                    Questpond
# 260  UCzWd8lsefYoh42OCrg6FzuQ                                BestITCourses
# 60   UCUstiGIdOUgLeZ8v9kXk7FA                              Code with Gauri
# 71   UCCktnahuRFYIBtNnKT5IYyg                                  Intellipaat
# 3    UC8butISFwT-Wl7EV0hUK0BQ                             freeCodeCamp.org
# 18   UC-ikyViYMM69joIAv7dlMsA                              DevOps on Azure
# 4    UC8butISFwT-Wl7EV0hUK0BQ                             freeCodeCamp.org
# 17   UCkw4JCwteGrDHIsyIIKo4tQ                                     edureka!
# 29   UCqu4KFiSMYjqL_V0QY_CZNw                              Virtual TechBox
# 97   UCNDfiL0D1LUeKWAkRE1xO5Q                            Pragmatic AI Labs
# 0    UCdngmbVKX1Tgre699-XLlUA                          TechWorld with Nana
# 222  UCzX9-dTqz-kG5q1-uys_NGw                              Behind my Cloud
# 44   UCNDfiL0D1LUeKWAkRE1xO5Q                            Pragmatic AI Labs
# 102  UCLcRBsiL_BIgDdn7P6uZbnQ                                 Joe Holbrook
# 1    UCkw4JCwteGrDHIsyIIKo4tQ                                     edureka!
# 169  UCObs0kLIrDjX2LLSybqNaEA                               Great Learning
#
#          videoId                                         videoTitle  \
# 215  lLubrB7zt6g                                DevOps Zero to Hero
# 406  KN5kv1Ya2vQ  QA: What is Quality Assurance #qualityassuranc...
# 318  anX7_5iZoWo  The Top 5 Must-Have DevOps Tools You Need for ...
# 307  OfTCfPylRUc  Cracking the DevOps Code: Courses & Certificat...
# 153  LO5Uj9o6fYs  It shouldn't be so annoying to run a container...
# 395  n2HGPoSuKfI  Red Hat DevOps Culture and Practices - the sec...
# 412  FT-2pkA2zhs  Changing behaviors makes you better...  #tech ...
# 325  1cTRjLrSOGw  What's the goal of Platform Engineering? #shor...
# 329  8bQBLmPKGww  Trunk-based dev causes burnout?  - State of De...
# 348  kMOAq1O8lCE  What are 15-factor apps and environment parity...
# 321  euzo4nuc0vo  Exploring CICD and Boosting Developer Producti...
# 255  NrxIH6ci0VE  Contribute to the 2023 DevOps survey, and Goog...
# 377  tY9vL-o6fMM  What is IAC? #terraform #coding #cloudsectiona...
# 342  aEFlTCzrK84               DevOps Journey: First month  #shorts
# 109  FZQQGERAggo       What is Containerization in Devops explained
# 300  VjXBFrEqmrU  Hiring for AWS Cloud | Work from Home | Remote...
# 399  _5jI2V1VJM0  What is CICD? #continuousdeployment #continuou...
# 130  c9jvQkPr7-8     What is DevOps Explained for Beginners #Shorts
# 182  gjdMgaeGTQM  Start Using Docker Today! #docker #devops #web...
# 409  TMdFl80hbp8  VSTS tutorial for beginners-VSTS Azure Devops-...
# 418  dHmkK6FLh8s  SonarQube tutorial-SonarQube integration with ...
# 400  Tw9NEMgA900  DevOps Engineer at Enterprise vs Startups #shorts
# 172  eemMLkC7I0I  How to share DevOps repos with other team memb...
# 416  YFl6FVBh1CU  Sematext Product and Feature Update #02 Pt.2 #...
# 151  kyEzRrB8FEs                                Demystifying DevOps
# 207  xQXpeCjQrlk                                     DevOps vs. SRE
# 344  VRRsHFoj3Yk  What is Git? How would you define Git? || #Git...
# 426  WNeymGyLiiE  Terraform or CloudFormation? Which is right Ia...
# 186  tqBFyJffkiY      What is DevOps? | One Dev Question: Abel Wang
# 142  LTSSsn_xy3E  Build Software Faster with The One DevOps Plat...
# 419  M5vS-MTb8So  DevOps / ITSM project management course (summa...
# 192  n6-9GkIJjpQ  Manually Fetching Elasticsearch Metrics #devop...
# 360  BGzXsKcVPy8  Differences in Roles of a DevOps Engineer vs S...
# 311  ia3IvqZUWSk                  DevOps Explained in Simple Terms!
# 314  JrMwo1WalSc  All that digital transformation, DevOps, etc. ...
# 73   B689nX--n6s  What is the Professional Cloud DevOps Engineer...
# 179  MHO72XPgOto  5 Features Of Azure DevOps #sandeepsoni #bestd...
# 384  q_S0ndGZb7k  Unlock Azure DevOps Potential: The Ultimate Gu...
# 242  xJ7eIvDB6C0  Redefine infrastructure as a DevOps Engineer a...
# 414  A0VZHGKVRAk                              The DevOps revolution
# 369  QIP57hj0tlw  Set up the Microsoft Azure DevOps Boards spoke...
# 336  61bP3rQD3DA  Azure DevOps Engineer Salary: The Complete Gui...
# 231  RXEMBw9liOo  How do you handle Databases in a DevOps world?...
# 410  Wcw0DMzqKFw                               DevOps in 60 Seconds
# 319  TOcAnwANYXo                             What is Secure DevOps?
# 120  5bs2nX6roc4  DevOps at Microsoft: Learn from teams at Micro...
# 273  44sQGpGMjLo  DevOps Learning Journey with AWS Skill Builder...
# 94   4urrNTGNL6Q  Barclays stays ahead of the competition with R...
# 190  qr0eaVUbduM                           Agile, Explained: DevOps
# 347  4nx7d30V3tY  Alex Fletcher (Lead Dev) - Global DevOps Exper...
# 37   cus7WYHdQic  What is DevOps? A Simple Explanation for Non-T...
# 315  reU4ALv2ctg      dbForge Source Control in the DevOps pipeline
# 299  dUrIDiRFPOE             DevOps is a part of Air Force history!
# 103  x9IeTQAau3Q  What is the difference between VSTS and Azure ...
# 203  yz0NB5tGcL4  Networking RoadMap | Networking for DevOps | N...
# 290  y84Fy-NkQkY  What DevOps practices can be applied to Machin...
# 227  lGo-OffoJQw  New Course Announcement | Networking for DevOp...
# 221  Uq-DYaRGW70       Oracle Cloud Infrastructure DevOps: Overview
# 328  gU_LM-JHqz0  Create a DevOps Project with HPE GreenLake for...
# 305  4xEllY41XHI  Can I use DevOps tooling for Machine Learning ...
# 376  VVlyCo8403U  Emily Chase (COO) - Global DevOps Experience P...
# 34   UZmwAu-2UYw  GitKraken Client 9.3 Release: Heaps of Azure D...
# 28   jyW3D74I3_w  What is DevOps? | DevOps in 2 Minutes | DevOps...
# 197  -lMuqSg-qqc  How does MLOps differ from DevOps? | One Dev Q...
# 274  bi0ZKWcwYr0  How to Integrate Database into Your DevOps Inf...
# 245  gZ7GtQ8XzYo  ROI of DevOps Transformation: How to quantify ...
# 309  _6LFV1WB-BM  Software-Defined Vehicle | How Can DevOps and ...
# 270  IQi7kU2XLnc  Lumen Tech boosts dev productivity and gains w...
# 379  zXsuvuQ2M_E              DevOps Config | Create an application
# 233  zaVTJVwtyzI                  Gemini for Cloud DevOps Engineers
# 212  Ta5kj4ghWBQ  Shell scales AI with the Microsoft DevOps plat...
# 401  2YdO4nLYfBo  Mobile DevOps Release Management for Android |...
# 385  SDVo6XvQmNw                                    What is DevOps?
# 176  vM5u992At94  SolarWinds Observability  A Unified Full-Stack...
# 39   3jIuBleAnQk  How to create a test plan in Azure DevOps to u...
# 394  QEk_gEVH8ls          Ogg Extensions for Microsoft Azure DevOps
# 214  33Aab--WKY0                 LogDNA | Log Management for DevOps
# 244  Z3QMHH2dHDg  Software-Defined Vehicle | How to Use DevOps i...
# 170  XQTOoJefbTg     DevOps at Microsoft: Innovating on open source
# 316  Dvd2TpJdEiU  Driving inclusion and diversity in DevOps with...
# 53   aFWi8ToAjpU  What is DevOps? (explained in a two minute car...
# 271  ufcvtLB8zCg           What Makes HCL Software DevOps Different
# 131  J0u4I1zXKBc      DevOps at Microsoft: Redefining IT monitoring
# 378  2cMC8LTW56M           How To Delete A Commit From Azure DevOps
# 163  lPRFzxOrQ5E  DevOps at Microsoft: Driving engineering excel...
# 126  IJZVNzpekzk      DevOps Culture and Practice Enablement Course
# 193  zkNI4Bce7ek        Accelerating DevOps with DORA Deutsche Bank
# 291  mfRV1A6axjE  Modern Requirements revolutionizing product de...
# 262  riqb7SRhLC4  Add diagrams to Azure DevOps tasks and stories...
# 113  w1-SgahfeZA      DevOps in a nutshell | Explained in 2 Minutes
# 33   PaO7Cb3v6XE              Salesforce Test Automation For DevOps
# 162  YHxcNu5fHcc                    base2Services - What is DevOps?
# 333  -p0NusREWu8  Bringing Security & DevOps Together | Making D...
# 100  IY9WvL95azs                 5 Essential DevOps Pipeline Stages
# 258  tsaZM9ipnRw  Novo Nordisk accelerates life-changing researc...
# 278  MOi5-3hz6Kg                     DevOps Analytics and Reporting
# 93   V2wAQXTWkdg  Evaluate candidates' DevOps engineering skills...
# 104  jqnbJsnX_iU                             Lets rethink IT DevOps
# 158  x6UCODfHerw                            Let's rethink IT DevOps
# 323  mcAZiiyH6lE                     DevOps Automation Tools: Top 5
# 380  n_9SFu8nSak  Full Stack Application Architecture | Follow T...
# 279  JAblex0uS4k  DevOps vs Platform Engineering: Platform Engin...
# 177  x39HTQxZCDc  How to perform Serverless operations with Azur...
# 189  QxTqEajKOqo  Quick tour of Azure DevOps Starter using Node....
# 392  dFTreqpnMb8  Strategic Execution: Turning plans into action...
# 292  jstqIuw_0aA  DevOps | Connect and configure an Azure DevOps...
# 306  Pe4_1lNvuqY  What Azure DevOps can do? DevOps Top Tips for ...
# 228  MmBrYiTJ1DI  Custom Design Release Notes like a Pro in Azur...
# 367  RmI540zIFCw  Master DevOps with Azure DevOps: A Comprehensi...
# 368  1h6F6EnY2Tg  ProcMan  The DevOps-Tool for Control-M, IWSz a...
# 282  1ShUrUPsIss  6 tips from DevOps Technical Recruiter | Job I...
# 353  T3F8fLfbscw  Prodly DevOps for Jira: Jira Integration for S...
# 257  SwqZAfoVE78  Creating Reliability with your customers | 202...
# 236  RWR3OWe3AkI  Azure Devops Tutorial for Beginners | What is ...
# 283  InuL9zQeBWc  How to Integrate ServiceNow and Azure DevOps i...
# 83   MSjr6sCUniE  DevOps vs Agile | DevOps Tutorial For Beginner...
# 41   Qm79wDSCZ-w  My Daily Routine as a DevOps Engineer | Realti...
# 420  5N3fubDNTHI  YohDev's Approach to Agile Web Development and...
# 345  KZKtOg5Rr6s             How to Install Exalate on Azure DevOps
# 383  YmbrbFUpcEI  Devops Engineer Apprentice: K4 Understanding t...
# 116  oDMEClYm_d0  What is the difference between DevOps and Plat...
# 366  lZRebX-0hu4    7 MUST HAVE Skills for your DevOps Engineer Job
# 275  LekmHt0dpkc  Growing a DevOps Agency and Creating Economic ...
# 293  G1296EbRuEI            DevOps Strategy: The Step-by-step Guide
# 223  ThhWOA5fK8k  Sync Azure DevOps Work Items to Asana Tasks wi...
# 146  mkLqknd8yHY  Mastering Azure DevOps - Part 3: Create Your P...
# 338  0lZEHwl1B8I           DevOps Automation 2024: Automation Tools
# 374  mGDhAFG-AlI    How does DevOps relate to platform engineering?
# 381  7vAabiy-ruw  Hyperautomation in DevOps: 3 Trends and 3 Chal...
# 269  F8-j0WVd4zQ   DevOps Trends Coming in 2024 | Easily Explained
# 86   9v9Et_ja3n4  The future of DevOps and the complexity of Kub...
# 122  tGvs2AoiULA  Mastering Azure DevOps - Part 1: Organizations...
# 302  rqKp-fFqHv0  Spotlight: Sasho Zahariev, Senior Cloud & DevO...
# 25   kBV8gPVZNEE                                    What is DevOps?
# 154  s_f3x7dbaBU                 How to Sync Jira with Azure DevOps
# 38   an8SrFtJBdM  DevOps vs SRE vs Platform Engineering | Clear ...
# 121  uhOZqiw7mdk  New AWS DevOps Professional (DOP-C02) certific...
# 134  YHznYB275Mg                     Traditional DevOps Daisy Chain
# 417  f3ikzEldD-0      I Can Read Secrets In Azure DevOps Pipelines!
# 340  uAR6ONWwNGU  LEARN These 7 DevOps Skills to STAY AHEAD in 2025
# 286  b_LMiSZCJkg  The ULTIMATE DevOps Roadmap For Beginners | Ho...
# 69   n35epEQaNcA       Should AI Help With Test Creation in DevOps?
# 346  i87e3Gw_k-w                     From DevOps to MLOps to LLMOps
# 334  gcUyKx4pN58    What Top CTOs Know About DevOps That You Don't!
# 65   AEqxnGrFYdo                    Streamline DevOps with Amazon Q
# 354  GLRf5-8aRDU                 The Top 4 DevOps Headlines of 2025
# 6    uTEL8Ff1Zvk  What's the Difference Between DevOps and SRE? ...
# 253  yBOyBcgWWBU  The Future of DevOps and Platform Engineering ...
# 408  ZOHPCCeEd98  What You Should Know About Permissions In Azur...
# 421  zj8BFk4w-gg  My Journey from DevOps to MLOps. Part 2/3: Dep...
# 259  xTuVvKWrKM0          Multi-cloud security made easy for DevOps
# 152  7tfaX9cGhjY     Clone git Repository using SSH in Azure DevOps
# 317  dOdTKpYUOAQ  Post "Accelerate": Why are we still failing at...
# 403  HGJP5qWr0QQ             Can I Write My Blog With Azure DevOps?
# 422  -vhVrL90Et4  Kubernetes and Docker Explained: A 5-Minute De...
# 361  OJY0H2fWlMo  Olakunle Abiola - Eco-DevOps - Building a Gree...
# 140  x56ZjJyS7Io            Sprint Retrospective using Azure DevOps
# 219  PplocJ2OYjI                     #FiveThings About Azure DevOps
# 26   UbtB4sMaaNM                                    What is DevOps?
# 220  hClhzxf7ePk  How to Create a Pre-Populated Azure DevOps Pro...
# 261  5xg9LCOVTFQ  Introduction to Jenkins, Continuous Integratio...
# 48   GQPzaq-owYM  Now SRE Everyone Else with CRE! (class SRE imp...
# 124  1P3eDs9Zzyk                  GitLab DevOps Platform 5 min Demo
# 125  WlXmTyF7a38  Mastering Azure DevOps - Part 4: Sprint Planni...
# 352  OU_L40yd3n0  Tools to learn for DevOps | How to get a job i...
# 312  08Ca-lZHtUs                       Lucid Cards for Azure DevOps
# 156  DUrMRhmTfRo  TachyonGPT, your work item-generating copilot ...
# 339  e1n1j3b6kYE  2. Azure DevOps AZ 400 - Azure DevOps Dashboar...
# 391  JwJCFT2aleE  Devops Role | Azure Devops Roles And responsib...
# 308  VqCnJvhz4g0   Roles and Responsibilities of DevOps Engineer...
# 101  umo6kKXD0-Q                 DevOps and Mainframe Modernization
# 372  ab_Y--gsjjU   Predicting 2024 Testing Trends|  Agile, DevOp...
# 201  RDeOqw0BtVM                              Is DevOps Just A Fad?
# 79   fKDRIVskET8  Is DevOps Right For You | DevOps Engineer Skil...
# 301  WOvHIG01lfE  How to Create Cron Jobs in Azure DevOps Pipeli...
# 370  toktof3m78E                    State of Devops 2023 Highlights
# 106  vAbl3X3VrJo                So You Want To Be A DevOps Engineer
# 349  6qd6GG3XQXA  Breaking down monoliths with Microservices and...
# 295  I9UUzVSxPI8                 How to Migrate TFS to Azure DevOps
# 211  H_OotOqUwcc  6-Months Plan to a High Paying AWS Cloud/DevOp...
# 76   zp1nzm_5SJg                           Azure Essentials: DevOps
# 284  T3p0ct4J9yc  Discover the Secrets to Quickly Mastering Azur...
# 423  YkaVE0Fm5KU  The most important thing to evolve DevOps is f...
# 413  _sXBtlA2YGY  DevOps for Java Developers| Ixchel Ruiz | The ...
# 92   4-z1-eEHhvs  Grafana, Observability, & DevOps | Grafana for...
# 205  _V9IJw91SXM  How to get DevOps skills even if you don't hav...
# 396  zL65tqWav7w  Practical DevOps: Continuous Delivery vs Conti...
# 217  T2RuHZCzrEE   The DevOps Handbook - Worth Software Engineering
# 165  sig5RKKofS8  What Is DevOps?  - Explained With Real World E...
# 183  9VLNHLnTi_w            Secure DevOps with Pulumi and Terraform
# 50   2q-5cNjZIi4  Netflix DevOps Practices for Quality and Speed...
# 191  -x1aDyvtaQU  Synapse CI/CD: Integrating your Workspace with...
# 75   HU3g1x_ohIY  Will AI replace DevOps Engineer? AI tools in D...
# 180  TkDjFaUWtwU  What is Azure DevOps? A beginners tutorial in ...
# 20   tEylFyxbDLE  SLIs, SLOs, SLAs, oh my! (class SRE implements...
# 19   w6RURa_LPgQ  Use DevOps to build cloud-native apps anywhere...
# 74   tnu1oFWzNpU  Testing Mobile Applications: Best Practices Yo...
# 46   KCzNd3StIoU             DevOps vs. SRE: What's the difference?
# 23   2zqMQ8K5m3I  (#2) What is Azure DevOps  | Azure DevOps Tuto...
# 129  YtTYdGls6Os  How Hard Is AWS Certified DevOps Engineer Prof...
# 11   3EyT1i0wYUY  What is DevOps? | DevOps Training - DevOps Int...
# 98   uvQYzYhuLLE  Will AI improve Developer and Testing Producti...
# 389  clorMbXvJaQ  Revolutionizing Cloud DevOps: Inside IBM's Gam...
# 359  siOxHUFJ8U8  Cloud Native On AWS: AWS DevOps Tools for Clou...
# ...
# 189                  333000               1311
# 392                     210                 31
# 292                   56900                328
# 306                     373                128
# 228                     961                 56
# 367                  135000               1162
# 368                      11                  8
# 282                    1250                 82
# 353                     415                 97
# 257                 1190000               5136
# 236                    6790                149
# 283                     709                158
# 83                    60700                802
# 41                     8680                222
# 420                     148                 31
# 345                     742                169
# 383                   80300               1345
# 116                   25300                605
# 366                     830                 14
# 275                  133000                189
# 293                    1840                177
# 223                     709                158
# 146                     354                 16
# 338                    1840                177
# 374                   29100               2350
# 381                  260000                532
# 269                    1840                177
# 86                      692                  7
# 122                     354                 16
# 302                     841                165
# 25                   437000               2059
# 154                     709                158
# 38                  1080000                134
# 121                   71600                337
# 134                   43400               1496
# 417                     214                112
# 340                    5430                139
# 286                     450                 29
# 69                   260000                532
# 346                    5520                327
# 334                    1700                688
# 65                  1770000               1077
# 354                   12600                999
# 6                   1190000               5136
# 253                   12800                578
# 408                     214                112
# 421                    2940                 30
# 259                 1190000               5136
# 152                     199                  8
# 317                    1670                601
# 403                     214                112
# 422                      11                 18
# 361                     538                100
# 140                      19                  1
# 219                  563000               7612
# 26                  1020000               1171
# 220                  563000               7612
# 261                   38900                216
# 48                  1190000               5136
# 124                   43400               1496
# 125                     354                 16
# 352                    2210                 74
# 312                  495000                389
# 156                     980                251
# 339                    2560                151
# 391                   71800                853
# 308                    1840                177
# 101                 1020000               1171
# 372                     815                454
# 201                   17600                217
# 79                   209000                439
# 301                    6060                 64
# 370                    3700                262
# 106                  142000                987
# 349                       7                  7
# 295                     103                 94
# 211                   26400                498
# 76                   353000                913
# 284                    4100                714
# 423                    6120               1389
# 413                    1670                601
# 92                    28000                851
# 205                   17600                217
# 396                    3700                262
# 217                      20                  2
# 165                  209000                439
# 183                   48100                306
# 50                   260000                532
# 191                   14800                269
# 75                   138000                246
# 180                    9500                131
# 20                  1190000               5136
# 19                   333000               1311
# 74                   260000                532
# 46                  1020000               1171
# 23                    89000                732
# 129                   16300                899
# 11                  4330000              11559
# 98                   260000                532
# 389                    4230                219
# 359                    1840                177
# 95                   209000                439
# 144                   82600                225
# 310                    1890                 88
# 85                    13100                 93
# 297                    2100                 92
# 280                   80300               1345
# 128                    3090                277
# 55                   209000                439
# 398                     148                 31
# 248                  563000               7612
# 78                   138000                246
# 304                  174000               1308
# 96                    28000                851
# 234                 1770000               1077
# 356                    3700                262
# 326                   72800                344
# 12                   543000               1208
# 159                  135000               1162
# 137                  135000               1162
# 263                   10700                110
# 77                   240000                100
# 119                    5010                209
# 54                   209000                439
# 397                     185                234
# 382                     214                112
# 110                   48100                306
# 393                     604                 58
# 59                  1020000               1171
# 198                   48100                306
# 288                  787000              17256
# 30                  1200000                126
# 133                  787000              17256
# 70                   288000                803
# 49                    17600                217
# 209                  220000                561
# 168                     354                 16
# 61                    17600                217
# 58                    48100                306
# 51                 11500000               4588
# 111                11500000               4588
# 281                   48100                306
# 45                  4690000               2469
# 276                    1840                177
# 91                  1190000               5136
# 185                     145                  9
# 332                     103                 94
# 21                    42600                111
# 404                     123                  7
# 216                    1250                228
# 24                    13000                 98
# 99                    48100                306
# 10                    89000                732
# 105                    1720                 16
# 175                   48100                306
# 141                  437000               2059
# 324                     830                 14
# 251                    6790                149
# 195                   20800                 75
# 267                   48400                470
# 143                  333000               1311
# 424                      32                 18
# 80                 11500000               4588
# 357                    1590                358
# 145                    1850                 21
# 88                    14800                269
# 164                 1770000               1077
# 272                  140000              10289
# 364                    1840                177
# 47                   260000                532
# 150                11500000               4588
# 173                  787000              17256
# 232                    2530                366
# 200                   49600               1101
# 247                  242000               2854
# 148                   11800                939
# 147                   48100                306
# 343                    2430                104
# 40                  1670000               1297
# 138                  353000                913
# 57                  1050000               3063
# 335                   48400                470
# 56                   135000               1162
# 226                   48100                306
# 90                    48100                306
# 63                   260000                532
# 181                   48100                306
# 64                     3310                 33
# 188                  563000               7612
# 218                 1770000               1077
# 117                    3090                277
# 36                  1200000                126
# 289                   49600               1101
# 298                    3500                 22
# 375                    1170                100
# 62                     1930                 52
# 8                   4330000              11559
# 415                     374                 29
# 22                  1200000                126
# 82                   163000               1696
# 225                   41000               1293
# 224                   80100               1460
# 206                  242000               2854
# 322                    1840                177
# 187                   30900               1046
# 388                    1670                601
# 266                   49600               1101
# 210                     240                 53
# 256                    3090                277
# 114                  333000               1311
# 66                   495000                511
# 132                  220000                561
# 240                     742                169
# 287                   23600               1691
# 199                     483                 20
# 204                   48100                306
# 89                 11500000               4588
# 277                    5430                139
# 331                    4680                212
# 112                    1570                 54
# 363                   95900               4709
# 230                   23600               1691
# 355                  140000              10289
# 9                   1200000                126
# 285                   23600               1691
# 194                11500000               4588
# 160                  141000                377
# 265                    1580                102
# 350                    2940                 30
# 196                    6940                 40
# 202                  242000               2854
# 373                  144000               4626
# 351                   23600               1691
# 390                    1670                601
# 254                   12600                999
# 252                   17600                217
# 81                 11500000               4588
# 303                   77700                838
# 123                  317000               2111
# 5                    524000                919
# 238                   13400                163
# 27                   107000                541
# 35                  4810000               8698
# 213                     526                 41
# 178                  140000              10289
# 313                   23600               1691
# 402                    4940                479
# 320                     538                100
# 425                    1590                358
# 264                     111                 37
# 149                   16600                234
# 327                   71800                853
# 296                    1670                601
# 371                   71800                853
# 2                   1050000               3063
# 118                    3090                277
# 67                 11500000               4588
# 15                   524000                919
# 72                     6500                 25
# 135                    3090                277
# 365                   12800                578
# 362                   12800                578
# 31                  1200000                126
# 250                   11300                418
# 167                   30500                384
# 157                  140000              10289
# 32                  1190000               5136
# 174                  140000              10289
# 52                 11500000               4588
# 229                     415                 97
# 294                   71800                853
# 341                   77700                838
# 107                 1190000               5136
# 241                   98500                879
# 155                    3090                277
# 42                   524000                919
# 268                 1190000               5136
# 246                  140000              10289
# 337                     672                 30
# 235                    7620                656
# 115                11500000               4588
# 237                  135000               1162
# 108                   30500                384
# 208                    2900                 51
# 184                  140000              10289
# 43                   787000              17256
# 16                   135000               1162
# 139                  135000               1162
# 161                   36600                348
# 243                  140000              10289
# 239                   85900               1154
# 358                     733                 84
# 330                   41800               1164
# 84                    12800                578
# 136                     476                  7
# 87                   140000              10289
# 127                   16600                234
# 386                     733                 84
# 171                 1770000               1077
# 7                   1200000                126
# 13                  4330000              11559
# 166                  135000               1162
# 249                     354                 16
# 407                      42                 11
# 405                    1590                358
# 411                     526                 41
# 387                    7310                 51
# 68                 11500000               4588
# 14                   220000                561
# 260                  135000               1162
# 60                     5730                 84
# 71                 11500000               4588
# 3                  10400000               1799
# 18                    48100                306
# 4                  10400000               1799
# 17                  4330000              11559
# 29                    19500                141
# 97                    17100               1160
# 0                   1200000                126
# 222                     158                139
# 44                    17100               1160
# 102                    9370                279
# 1                   4330000              11559
# 169                  922000               2127
# DataFrame saved as DC_2025-01-29_01:18:14_427_records.json
# Destination directory already exists
# Push successful.
